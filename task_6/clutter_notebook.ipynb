# %% [markdown]
# scp /Users/loveredin/Documents/GitHub/02613_mini_project/task_6/task_5_and_6.py s253013@login.hpc.dtu.dk:scripts/mini_project/task_6/task_5_and_6.py
#
# scp /Users/loveredin/Documents/GitHub/02613_mini_project/task_6/task_6.sh s253013@login.hpc.dtu.dk:scripts/mini_project/task_6/task_6.sh
